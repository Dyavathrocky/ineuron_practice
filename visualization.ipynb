# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
np.random.seed(20)
df = pd.DataFrame(np.random.rand(1000,1) , index= pd.date_range('2021-07-18' , periods=1000) , columns=['data'])

# %%
df
# Out:
#                 data
# 2021-07-18  0.588131
# 2021-07-19  0.897714
# 2021-07-20  0.891531
# 2021-07-21  0.815837
# 2021-07-22  0.035890
# ...              ...
# 2024-04-08  0.992189
# 2024-04-09  0.756037
# 2024-04-10  0.299186
# 2024-04-11  0.261712
# 2024-04-12  0.968979
#
# [1000 rows x 1 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.data.cumsum().plot()
# Out:
# <AxesSubplot:>

# %%
df['data1'] = df.data.cumsum()

# %%
df['data2'] = df['data'].apply(lambda x : x*14)

# %%
df
# Out:
#                 data       data1      data2
# 2021-07-18  0.588131    0.588131   8.233831
# 2021-07-19  0.897714    1.485845  12.567992
# 2021-07-20  0.891531    2.377375  12.481430
# 2021-07-21  0.815837    3.193213  11.421725
# 2021-07-22  0.035890    3.229102   0.502454
# ...              ...         ...        ...
# 2024-04-08  0.992189  495.812936  13.890642
# 2024-04-09  0.756037  496.568973  10.584522
# 2024-04-10  0.299186  496.868159   4.188610
# 2024-04-11  0.261712  497.129872   3.663973
# 2024-04-12  0.968979  498.098851  13.565706
#
# [1000 rows x 3 columns]

# %%
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df1 = sns.load_dataset('iris')

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.plot()
# Out:
# <AxesSubplot:>

# %%
gf = df1.plot(figsize=(20,10), title="irish data")

# %%
df1.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
gf = df1.plot(figsize=(5,6), title="irish data")
gf.set_xlabel("this is my x axis")
# Out:
# Text(0.5, 0, 'this is my x axis')

# %%
df1.iloc[0][0:4].plot(kind = "bar")
# Out:
# <AxesSubplot:>

# %%
df2 = sns.load_dataset('titanic')

# %%
df2
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df2['pclass'].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df3 = pd.DataFrame(np.random.rand(10,4), columns=['a','b','c','d'])

# %%
df3
# Out:
#           a         b         c         d
# 0  0.754462  0.591334  0.108692  0.402853
# 1  0.269676  0.573075  0.916855  0.189785
# 2  0.944349  0.820192  0.229638  0.697904
# 3  0.701251  0.570189  0.448045  0.332812
# 4  0.108018  0.121464  0.420368  0.336497
# 5  0.389588  0.301919  0.312265  0.036205
# 6  0.378922  0.010581  0.357048  0.083158
# 7  0.705395  0.816193  0.262531  0.382466
# 8  0.897100  0.437109  0.842188  0.852225
# 9  0.123356  0.150039  0.214021  0.006917

# %%
df3.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df3.plot.barh()
# Out:
# <AxesSubplot:>

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df1['sepal_length'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.plot(kind= "hist", stacked= True , bins = 100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.plot(kind= "hist", stacked= True , bins = 100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.plot(kind= "hist", stacked= True , bins = 100, figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.hist(figsize=(10,10), color= ['red'], alpha=0.1)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df1.plot.scatter(x = 'sepal_width' , y = 'petal_width')
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>

# %%
df1.plot.scatter(x = 'sepal_length' , y = 'petal_width',  c = 'petal_length', s = 80)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>

# %%
df1.plot.hexbin(x = 'sepal_length' , y = 'petal_width' , gridsize=10)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>

# %%
df
# Out:
#                 data       data1      data2
# 2021-07-18  0.588131    0.588131   8.233831
# 2021-07-19  0.897714    1.485845  12.567992
# 2021-07-20  0.891531    2.377375  12.481430
# 2021-07-21  0.815837    3.193213  11.421725
# 2021-07-22  0.035890    3.229102   0.502454
# ...              ...         ...        ...
# 2024-04-08  0.992189  495.812936  13.890642
# 2024-04-09  0.756037  496.568973  10.584522
# 2024-04-10  0.299186  496.868159   4.188610
# 2024-04-11  0.261712  497.129872   3.663973
# 2024-04-12  0.968979  498.098851  13.565706
#
# [1000 rows x 3 columns]

# %%
d = df.iloc[0]

# %%
d.plot.pie(figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='2021-07-18 00:00:00'>

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris = df1.head(3).T

# %%
iris.iloc[0:4].plot.pie(subplots=True , figsize=(20,25), fontsize=25, autopct='%.2f')
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
pd.plotting.scatter_matrix(df1 , figsize=(20,20), alpha=0.9 , diagonal='kde')
# Out:
# array([[<AxesSubplot:xlabel='sepal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>,
# ...

# %%
df['data'].plot(style='blue', legend= True , label="rocky")
# Out:
# <AxesSubplot:>

# %%
# !pip install plotly
# !pip install cufflinks

# %%
# !pip install plotly
# !pip install cufflinks

# %%
from plotly.offline import iplot
import plotly as py
import plotly.tools as tls
import cufflinks as cf

# %%
py.__version__
# Out:
# '5.1.0'

# %%
py.offline.init_notebook_mode(connected=True)
cf.go_offline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <function cufflinks.offline.go_offline(connected=None)>

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
py.offline.init_notebook_mode(connected=True) 
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
# ...

# %%
df1.iplot()
# Out:
# <div>                            <div id="7181425c-e2c9-4333-98b1-213ee52b80ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1.plot()
# Out:
# <AxesSubplot:>

# %%
df2.iplot(kind='scatter', x = 'fare' , y='age', mode='markers')
# Out:
# <div>                            <div id="b5af8128-f896-486e-b07d-43bcf520ec23" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
cf.getThemes()
# Out:
# ['ggplot', 'pearl', 'solar', 'space', 'white', 'polar', 'henanigans']

# %%
cf.set_config_file(theme='solar')
df2.iplot(kind='scatter', x = 'fare' , y='age', mode='markers')
# Out:
# <div>                            <div id="ab345159-f8da-4547-aab3-ce53fce5e8f4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
#bar , pychart , scatterplot , linear plot , 3D plot ,

# %%
# !pip install bokeh

# %%
import random

from bokeh.plotting import figure, show

# generate some data (1-10 for x, random values for y)
x = list(range(0, 26))
y = random.sample(range(0, 100), 26)

# generate list of rgb hex colors in relation to y
colors = ["#%02x%02x%02x" % (255, int(round(value * 255 / 100)), 255) for value in y]

# create new plot
p = figure(
    title="Vectorized colors example",
    sizing_mode="stretch_width",
    max_width=500,
    plot_height=250,
)

# add circle and line renderers
line = p.line(x, y, line_color="blue", line_width=1)
circle = p.circle(x, y, fill_color=colors, line_color="blue", size=15)

# show the results
show(p)

# %%
from bokeh.io import show
from bokeh.palettes import Turbo256
from bokeh.plotting import figure
from bokeh.transform import linear_cmap

# generate data
x = list(range(-32, 33))
y = [i**2 for i in x]

# create linear color mapper
mapper = linear_cmap(field_name="y", palette=Turbo256, low=min(y), high=max(y))

# create plot
p = figure(plot_width=500, plot_height=250)

# create circle renderer with color mapper
p.circle(x, y, color=mapper, size=10)

show(p)

# %%
df1.plot.hexbin(x = 'sepal_length' , y = 'petal_width' , gridsize=10)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
xy = df1[3:9]

# %%
xy
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa

# %%
xy.plot(kind="bar" , legend="hi", figsize=(20,20))
# Out:
# <AxesSubplot:>
